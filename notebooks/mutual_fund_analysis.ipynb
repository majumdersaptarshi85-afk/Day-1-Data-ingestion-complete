# %% [markdown]
# # Mutual Fund Data Analysis
# This notebook explores and analyzes mutual fund data including NAV trends, performance comparisons, and fund characteristics.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
sns.set_style('whitegrid')

# %% [markdown]
# ## 2. Load Data

# %%
# Load fund master data
fund_master = pd.read_csv('../data/raw/fund_master.csv')
print('Fund Master Data Shape:', fund_master.shape)
print('\nFirst few rows:')
print(fund_master.head())
print('\nColumns:', fund_master.columns.tolist())
print('\nData Types:')
print(fund_master.dtypes)

# %%
# Load fund NAV data (example with one fund)
try:
    axis_data = pd.read_csv('../data/raw/Axis_Bluechip.csv')
    print('Axis Bluechip Data Shape:', axis_data.shape)
    print('\nFirst few rows:')
    print(axis_data.head())
except Exception as e:
    print(f'Error loading Axis data: {e}')

# %% [markdown]
# ## 3. Data Exploration

# %%
# Summary statistics
print('Fund Master Summary:')
print(fund_master.describe())
print('\nMissing Values:')
print(fund_master.isnull().sum())

# %% [markdown]
# ## 4. Fund Analysis

# %%
# Add analysis code here
# Example: Compare fund performance across different schemes
# Visualize NAV trends
# Calculate returns and statistics

# %% [markdown]
# ## 5. Visualizations

# %%
# Add visualization code here
# Example: Plot NAV trends, compare funds, analyze correlations

# %% [markdown]
# ## 6. Conclusions

# %%
# Add insights and conclusions here
